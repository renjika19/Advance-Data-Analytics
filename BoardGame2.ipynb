# %%
import pandas as pd

from sqlalchemy import create_engine

# %%
db_file = r'database.sqlite'
engine = create_engine(r"sqlite:///{}".format(db_file))

# %%
sql = "SELECT name FROM sqlite_master WHERE type = 'table';"

table_names = pd.read_sql(sql, engine)
table_names
# Out:
#                        name
# 0                BoardGames
# 1         bgg.ldaOut.topics
# 2      bgg.ldaOut.top.terms
# 3  bgg.ldaOut.top.documents
# 4                bgg.topics

# %%
sql = "SELECT * FROM BoardGames;"

BoardGames_df = pd.read_sql(sql,engine)
BoardGames_df.head()
# Out:
#   row_names game.id  game.type  \
# 0         1       1  boardgame
# 1         2       2  boardgame
# 2         3       3  boardgame
# 3         4       4  boardgame
# 4         5       5  boardgame
#
#                                  details.description  \
# 0  Die Macher is a game about seven sequential po...
# 1  Dragonmaster is a trick-taking card game based...
# 2  Part of the Knizia tile-laying trilogy, Samura...
# 3  When you see the triangular box and the luxuri...
# 4  In Acquire, each player strategically invests ...
#
#                                   details.image  details.maxplayers  \
# 0   //cf.geekdo-images.com/images/pic159509.jpg                 5.0
# 1   //cf.geekdo-images.com/images/pic184174.jpg                 4.0
# 2  //cf.geekdo-images.com/images/pic3211873.jpg                 4.0
# 3   //cf.geekdo-images.com/images/pic285299.jpg                 4.0
# 4   //cf.geekdo-images.com/images/pic342163.jpg                 6.0
#
# ...

# %%
BoardGames_df.shape
# Out:
# (90400, 81)

# %%
sql = "SELECT * FROM [bgg.ldaOut.topics];"
BoardGameTopics_df = pd.read_sql(sql, engine)
BoardGameTopics_df.head()
# Out:
#         row_names  topics(bgg.ldaOut)
# 0      Die.Macher                   8
# 1    Dragonmaster                   5
# 2         Samurai                  22
# 3  Tal.der.Könige                   4
# 4         Acquire                   4

# %%
BoardGameTopics_df.shape
# Out:
# (29229, 2)

# %%
sql = "SELECT * FROM [bgg.ldaOut.top.terms]"
BoardGameTopTerm_df = pd.read_sql(sql,engine)
BoardGameTopTerm_df.head()
# Out:
#   row_names  topic                     term      beta
# 0         1      1        Bluffing.category  0.183436
# 1         2      1       Deduction.category  0.164224
# 2         3      1    Partnerships.mechanic  0.080226
# 3         4      1       PartyGame.category  0.066343
# 4         5      1  Murder.Mystery.category  0.048674

# %%
BoardGameTopTerm_df.shape
# Out:
# (250, 4)

# %%
sql = "SELECT * FROM [bgg.topics]"
BoardGameTopics2_df = pd.read_sql(sql,engine)
BoardGameTopics2_df.head()
# Out:
#   row_names game.id  game.type  details.maxplayers  details.maxplaytime  \
# 0         1       1  boardgame                 5.0                240.0
# 1         2       2  boardgame                 4.0                 30.0
# 2         3       3  boardgame                 4.0                 60.0
# 3         4       4  boardgame                 4.0                 60.0
# 4         5       5  boardgame                 6.0                 90.0
#
#    details.minage  details.minplayers  details.minplaytime    details.name  \
# 0            14.0                 3.0                240.0      Die Macher
# 1            12.0                 3.0                 30.0    Dragonmaster
# 2            10.0                 2.0                 30.0         Samurai
# 3            12.0                 2.0                 60.0  Tal der Könige
# 4            12.0                 3.0                 90.0         Acquire
#
#    details.playingtime            ...             \
# ...

# %%
BoardGameTopics2_df.shape
# Out:
# (29313, 74)

# %%
sql = "SELECT * FROM [bgg.ldaOut.top.documents]"
BoardGameTopDocuments_df = pd.read_sql(sql,engine)
BoardGameTopDocuments_df.head()
# Out:
#   row_names                                           document  topic  \
# 0         1                           The.Lounge..A.Mafia.Game      1
# 1         2                Ultimate.Werewolf..Ultimate.Edition      1
# 2         3  Ultimate.Werewolf..Deluxe.Edition.For.Kickstarter      1
# 3         4                                           Werewolf      1
# 4         5                     Παλέρμο..Το.Μεγάλο.Ξεκαθάρισμα      1
#
#       gamma
# 0  0.203125
# 1  0.200000
# 2  0.200000
# 3  0.194805
# 4  0.190476

# %%
BoardGameTopDocuments_df.shape
# Out:
# (288, 4)
